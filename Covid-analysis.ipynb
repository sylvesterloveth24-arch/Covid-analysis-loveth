# %% [markdown]
# <a href="https://colab.research.google.com/github/sylvesterloveth24-arch/Covid-analysis-loveth/blob/main/Covid-analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive

# Mount Google Drive to give Colab access to your files
drive.mount('/content/drive')

# File path to epidemiology.csv in your Google Drive root
file_path = '/content/drive/MyDrive/epidemiology.csv'

# Load the dataset into a Pandas DataFrame
df = pd.read_csv(file_path)

display(df.head())
print("Dataset Shape:", df.shape)
# Out:
# Mounted at /content/drive
#          date location_key  new_confirmed  new_deceased  new_recovered  \
# 0  2020-01-01           AD            0.0           0.0            NaN
# 1  2020-01-02           AD            0.0           0.0            NaN
# 2  2020-01-03           AD            0.0           0.0            NaN
# 3  2020-01-04           AD            0.0           0.0            NaN
# 4  2020-01-05           AD            0.0           0.0            NaN
#
#    new_tested  cumulative_confirmed  cumulative_deceased  \
# 0         NaN                   0.0                  0.0
# 1         NaN                   0.0                  0.0
# 2         NaN                   0.0                  0.0
# 3         NaN                   0.0                  0.0
# 4         NaN                   0.0                  0.0
#
#    cumulative_recovered  cumulative_tested
# 0                   NaN                NaN
# 1                   NaN                NaN
# ...
